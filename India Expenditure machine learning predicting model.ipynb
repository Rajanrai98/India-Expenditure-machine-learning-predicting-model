# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\WorldExpenditures.csv")

# %%
data
# Out:
#        Unnamed: 0  Year                   Country  \
# 0               0  2000                 Australia
# 1               1  2000                 Australia
# 2               2  2000                 Australia
# 3               3  2000                 Australia
# 4               4  2000                 Australia
# ...           ...   ...                       ...
# 25728       25728  2021  United States of America
# 25729       25729  2021  United States of America
# 25730       25730  2021  United States of America
# 25731       25731  2021  United States of America
# 25732       25732  2021  United States of America
#
#                                            Sector  Expenditure(million USD)  \
# 0                                  Total function                153122.633
# 1      Agriculture, forestry, fishing and hunting                  2195.583
# 2          Mining, manufacturing and construction                   905.018
# ...

# %%
data_aus = data[data["Country"] == "Australia"]

# %%
data_aus
# Out:
#        Unnamed: 0  Year    Country  \
# 0               0  2000  Australia
# 1               1  2000  Australia
# 2               2  2000  Australia
# 3               3  2000  Australia
# 4               4  2000  Australia
# ...           ...   ...        ...
# 24686       24686  2021  Australia
# 24687       24687  2021  Australia
# 24688       24688  2021  Australia
# 24689       24689  2021  Australia
# 24690       24690  2021  Australia
#
#                                                 Sector  \
# 0                                       Total function
# 1           Agriculture, forestry, fishing and hunting
# 2               Mining, manufacturing and construction
# 3                                            Transport
# 4                                      Fuel and energy
# ...                                                ...
# 24686                 Recreation, culture and religion
# 24687  General economic, commercial and labour affairs
# ...

# %%
data_ind = data[data["Country"] == "India"]

# %%
data_ind
# Out:
#        Unnamed: 0  Year Country                            Sector  \
# 11864       11864  2011   India                    Total function
# 11865       11865  2011   India            Environment protection
# 11866       11866  2011   India   Housing and community amenities
# 11867       11867  2011   India                            Health
# 11868       11868  2011   India                         Education
# ...           ...   ...     ...                               ...
# 23869       23869  2020   India                 Social protection
# 23870       23870  2020   India           General public services
# 23871       23871  2020   India                           Defence
# 23872       23872  2020   India           Public order and safety
# 23873       23873  2020   India  Recreation, culture and religion
#
#        Expenditure(million USD)    GDP(%)
# 11864                469224.363  25.06650
# 11865                   359.114   0.01918
# 11866                 26032.737   1.39070
# ...

# %%
data_ind.isnull().sum()
# Out:
# Unnamed: 0                  0
# Year                        0
# Country                     0
# Sector                      0
# Expenditure(million USD)    0
# GDP(%)                      0
# dtype: int64

# %%
data_ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 11864 to 23873
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                100 non-null    int64
#  1   Year                      100 non-null    int64
#  2   Country                   100 non-null    object
#  3   Sector                    100 non-null    object
#  4   Expenditure(million USD)  100 non-null    float64
#  5   GDP(%)                    100 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 5.5+ KB

# %%
data_ind.duplicated().any()
# Out:
# False

# %%
data_ind.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Country', 'Sector', 'Expenditure(million USD)',
#        'GDP(%)'],
#       dtype='object')

# %%
data_ind  = data_ind.drop(["Unnamed: 0"] , axis = 1)

# %%
data_ind
# Out:
#        Year Country                            Sector  \
# 11864  2011   India                    Total function
# 11865  2011   India            Environment protection
# 11866  2011   India   Housing and community amenities
# 11867  2011   India                            Health
# 11868  2011   India                         Education
# ...     ...     ...                               ...
# 23869  2020   India                 Social protection
# 23870  2020   India           General public services
# 23871  2020   India                           Defence
# 23872  2020   India           Public order and safety
# 23873  2020   India  Recreation, culture and religion
#
#        Expenditure(million USD)    GDP(%)
# 11864                469224.363  25.06650
# 11865                   359.114   0.01918
# 11866                 26032.737   1.39070
# 11867                 18813.825   1.00506
# 11868                 82567.205   4.41083
# ...                         ...       ...
# ...

# %%
data_ind.columns
# Out:
# Index(['Year', 'Country', 'Sector', 'Expenditure(million USD)', 'GDP(%)'], dtype='object')

# %%
data_ind
# Out:
#        Year Country                            Sector  \
# 11864  2011   India                    Total function
# 11865  2011   India            Environment protection
# 11866  2011   India   Housing and community amenities
# 11867  2011   India                            Health
# 11868  2011   India                         Education
# ...     ...     ...                               ...
# 23869  2020   India                 Social protection
# 23870  2020   India           General public services
# 23871  2020   India                           Defence
# 23872  2020   India           Public order and safety
# 23873  2020   India  Recreation, culture and religion
#
#        Expenditure(million USD)    GDP(%)
# 11864                469224.363  25.06650
# 11865                   359.114   0.01918
# 11866                 26032.737   1.39070
# 11867                 18813.825   1.00506
# 11868                 82567.205   4.41083
# ...                         ...       ...
# ...

# %%
for i in ['Expenditure(million USD)', 'GDP(%)']:
    plt.figure(figsize = (19,8))
    sn.lineplot(data_ind[i])
    plt.title(i)
    plt.grid()
    plt.tight_layout()
    plt.show()

# %%
for i in ['Expenditure(million USD)', 'GDP(%)']:
    plt.figure(figsize = (19,8))
    sn.distplot(data_ind[i])
    plt.title(i)
    plt.grid()
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6252\4092422434.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data_ind[i])
# C:\Users\user\AppData\Local\Temp\ipykernel_6252\4092422434.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data_ind[i])

# %%
data_ind.skew()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6252\2037765575.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_ind.skew()
# Year                        0.000000
# Expenditure(million USD)    2.840274
# GDP(%)                      2.599582
# dtype: float64

# %%
data_ind.kurtosis()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6252\976480098.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_ind.kurtosis()
# Year                       -1.225247
# Expenditure(million USD)    7.371693
# GDP(%)                      5.402716
# dtype: float64

# %%
data_ind.describe()
# Out:
#               Year  Expenditure(million USD)      GDP(%)
# count   100.000000                100.000000  100.000000
# mean   2015.500000              97187.859730    4.192584
# std       2.886751             169732.111508    7.139874
# min    2011.000000                229.927000    0.010040
# 25%    2013.000000              25009.304750    1.185068
# 50%    2015.500000              44463.491000    1.738810
# 75%    2018.000000              73778.395750    3.336370
# max    2020.000000             850750.546000   31.837040

# %%
data_ind.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6252\2835991059.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_ind.corr()
#                               Year  Expenditure(million USD)    GDP(%)
# Year                      1.000000                  0.118913  0.030381
# Expenditure(million USD)  0.118913                  1.000000  0.983483
# GDP(%)                    0.030381                  0.983483  1.000000

# %%
data_ind
# Out:
#        Year Country                            Sector  \
# 11864  2011   India                    Total function
# 11865  2011   India            Environment protection
# 11866  2011   India   Housing and community amenities
# 11867  2011   India                            Health
# 11868  2011   India                         Education
# ...     ...     ...                               ...
# 23869  2020   India                 Social protection
# 23870  2020   India           General public services
# 23871  2020   India                           Defence
# 23872  2020   India           Public order and safety
# 23873  2020   India  Recreation, culture and religion
#
#        Expenditure(million USD)    GDP(%)
# 11864                469224.363  25.06650
# 11865                   359.114   0.01918
# 11866                 26032.737   1.39070
# 11867                 18813.825   1.00506
# 11868                 82567.205   4.41083
# ...                         ...       ...
# ...

# %%
sn.scatterplot(x = "Expenditure(million USD)" , y = "GDP(%)" , data = data_ind)
# Out:
# <Axes: xlabel='Expenditure(million USD)', ylabel='GDP(%)'>

# %%
plt.figure(figsize = (50,8))
sn.countplot(x = "Sector" , data = data_ind )
# Out:
# <Axes: xlabel='Sector', ylabel='count'>

# %%
sn.lineplot(x = "Expenditure(million USD)" , y = "GDP(%)" , data = data_ind )
# Out:
# <Axes: xlabel='Expenditure(million USD)', ylabel='GDP(%)'>

# %%
plt.figure(figsize = (40,8))
sn.barplot(x = "Sector"  , y = "Expenditure(million USD)" , data = data_ind)
# Out:
# <Axes: xlabel='Sector', ylabel='Expenditure(million USD)'>

# %%
plt.boxplot(data_ind["Expenditure(million USD)"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x179cbb32b30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x179cbb33070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x179cbb32890>],
#  'medians': [<matplotlib.lines.Line2D at 0x179cbb33520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x179cbb337c0>],
#  'means': []}

# %%
q1 = data_ind["Expenditure(million USD)"].quantile(0.25)
q3 = data_ind["Expenditure(million USD)"].quantile(0.75)
iqr = q3-q1
upper_bound = q3+1.5*(iqr)
lower_bound = q1-1.5*(iqr)
print(upper_bound)
print(lower_bound)
# Out:
# 146932.03225
# -48144.33174999999

# %%
data_ind = data_ind[~((data_ind["Expenditure(million USD)"]>upper_bound))|((data_ind["Expenditure(million USD)"]<lower_bound))]

# %%
data_ind
# Out:
#        Year Country                            Sector  \
# 11865  2011   India            Environment protection
# 11866  2011   India   Housing and community amenities
# 11867  2011   India                            Health
# 11868  2011   India                         Education
# 11869  2011   India                 Social protection
# ...     ...     ...                               ...
# 23869  2020   India                 Social protection
# 23870  2020   India           General public services
# 23871  2020   India                           Defence
# 23872  2020   India           Public order and safety
# 23873  2020   India  Recreation, culture and religion
#
#        Expenditure(million USD)   GDP(%)
# 11865                   359.114  0.01918
# 11866                 26032.737  1.39070
# 11867                 18813.825  1.00506
# 11868                 82567.205  4.41083
# 11869                 25745.189  1.37534
# ...                         ...      ...
# ...

# %%
data_ind = data_ind.drop(['Country'] , axis = 1)

# %%
plt.boxplot(data_ind["Expenditure(million USD)"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x179cbbc41c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x179cbbc45e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x179cbb93ee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x179cbbc4b20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x179cbbc4dc0>],
#  'means': []}

# %%
data_ind
# Out:
#        Year                            Sector  Expenditure(million USD)  \
# 11865  2011            Environment protection                   359.114
# 11866  2011   Housing and community amenities                 26032.737
# 11867  2011                            Health                 18813.825
# 11868  2011                         Education                 82567.205
# 11869  2011                 Social protection                 25745.189
# ...     ...                               ...                       ...
# 23869  2020                 Social protection                 62045.909
# 23870  2020           General public services                130710.818
# 23871  2020                           Defence                 73508.743
# 23872  2020           Public order and safety                 47179.534
# 23873  2020  Recreation, culture and religion                  4647.868
#
#         GDP(%)
# 11865  0.01918
# 11866  1.39070
# 11867  1.00506
# 11868  4.41083
# 11869  1.37534
# ...

# %%
from sklearn.preprocessing import LabelEncoder , StandardScaler

# %%
data = data_ind["Sector"]

# %%
data
# Out:
# 11865              Environment protection
# 11866     Housing and community amenities
# 11867                              Health
# 11868                           Education
# 11869                   Social protection
#                        ...
# 23869                   Social protection
# 23870             General public services
# 23871                             Defence
# 23872             Public order and safety
# 23873    Recreation, culture and religion
# Name: Sector, Length: 90, dtype: object

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#                                  Sector
# 11865            Environment protection
# 11866   Housing and community amenities
# 11867                            Health
# 11868                         Education
# 11869                 Social protection
# ...                                 ...
# 23869                 Social protection
# 23870           General public services
# 23871                           Defence
# 23872           Public order and safety
# 23873  Recreation, culture and religion
#
# [90 rows x 1 columns]

# %%
le = LabelEncoder()
data = data.apply(le.fit_transform)

# %%
data_ind = data_ind.drop(["Sector"] , axis = 1)

# %%
data_ind = pd.concat([data_ind , data] , axis = 1)

# %%
data_ind
# Out:
#        Year  Expenditure(million USD)   GDP(%)  Sector
# 11865  2011                   359.114  0.01918       2
# 11866  2011                 26032.737  1.39070       5
# 11867  2011                 18813.825  1.00506       4
# 11868  2011                 82567.205  4.41083       1
# 11869  2011                 25745.189  1.37534       8
# ...     ...                       ...      ...     ...
# 23869  2020                 62045.909  2.32190       8
# 23870  2020                130710.818  4.89150       3
# 23871  2020                 73508.743  2.75087       0
# 23872  2020                 47179.534  1.76557       6
# 23873  2020                  4647.868  0.17393       7
#
# [90 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x = data_ind.drop(["Expenditure(million USD)"] , axis = 1)
y = data_ind["Expenditure(million USD)"]

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.20 , random_state = 42)

# %%
x_train.shape , x_test.shape
# Out:
# ((72, 3), (18, 3))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([ 39105.44098078,  31316.01070984,  58532.88873446,  42133.29006739,
#        -10938.68899633,  -2346.36509458, 101280.15196208,  35098.14006545,
#         23215.56734948,   3120.12441962,  11255.50885789,   -266.02546399,
#         32222.99989933, 124619.56976485,  91950.25975296,  20493.81342766,
#         -5986.93409961,  36104.15290154])

# %%
mse = np.mean((y_test-y_pred)**2)

# %%
print("mse_linear:",mse)
# Out:
# mse_linear: 32858084.91402793

# %%
pd.DataFrame({"y_test":y_test , "y_pred":y_pred})
# Out:
#            y_test         y_pred
# 17076   37609.304   39105.440981
# 14390   31224.186   31316.010710
# 19821   62247.997   58532.888734
# 21177   43183.565   42133.290067
# 11865     359.114  -10938.688996
# 14394    3485.623   -2346.365095
# 17075   94791.671  101280.151962
# 21172   34778.046   35098.140065
# 13093   25745.719   23215.567349
# 17080    4405.011    3120.124420
# 23865     562.270   11255.508858
# 15705    3380.168    -266.025464
# 19822   32563.617   32222.999899
# 23870  130710.818  124619.569765
# 13095   80612.706   91950.259753
# 11869   25745.189   20493.813428
# 14386     391.823   -5986.934100
# 15698   35255.237   36104.152902

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_tree = DecisionTreeRegressor(criterion = 'friedman_mse' , max_depth = 5)

# %%
model_tree.fit(x_train , y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=5)

# %%
y_pred_tree = model_tree.predict(x_test)

# %%
y_pred_tree
# Out:
# array([ 39429.436   ,  30960.7512  ,  65877.485   ,  41987.3565  ,
#           366.986   ,   3239.689   ,  88791.629   ,  38267.0665  ,
#         25292.849875,   3917.089   ,    601.92    ,   3172.884   ,
#         38267.0665  , 131101.495   ,  83334.722   ,  25292.849875,
#           366.986   ,  39429.436   ])

# %%
mse_tree = np.mean((y_test-y_pred_tree)**2)

# %%
mse_tree
# Out:
# 6912715.979791382

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize = (24,12))
plot_tree(model_tree , filled = True)
# Out:
# [Text(0.5229166666666667, 0.9166666666666666, 'x[1] <= -0.06\nfriedman_mse = 1079888202.677\nsamples = 72\nvalue = 45462.926'),
#  Text(0.26666666666666666, 0.75, 'x[1] <= -1.01\nfriedman_mse = 268863095.762\nsamples = 40\nvalue = 21920.055'),
#  Text(0.13333333333333333, 0.5833333333333334, 'x[2] <= 0.262\nfriedman_mse = 3537959.929\nsamples = 14\nvalue = 2193.605'),
#  Text(0.06666666666666667, 0.4166666666666667, 'x[0] <= 0.643\nfriedman_mse = 17130.22\nsamples = 7\nvalue = 357.636'),
#  Text(0.03333333333333333, 0.25, 'x[1] <= -1.435\nfriedman_mse = 2148.326\nsamples = 5\nvalue = 280.613'),
#  Text(0.016666666666666666, 0.08333333333333333, 'friedman_mse = 354.065\nsamples = 4\nvalue = 259.02'),
#  Text(0.05, 0.08333333333333333, 'friedman_mse = 0.0\nsamples = 1\nvalue = 366.986'),
#  Text(0.1, 0.25, 'x[1] <= -1.43\nfriedman_mse = 2675.786\nsamples = 2\nvalue = 550.192'),
#  Text(0.08333333333333333, 0.08333333333333333, 'friedman_mse = 0.0\nsamples = 1\nvalue = 498.464'),
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_forest = RandomForestRegressor(n_estimators = 100 , max_features = 5)

# %%
model_forest.fit(x_train , y_train)
# Out:
# RandomForestRegressor(max_features=5)

# %%
y_pred_forest = model_forest.predict(x_test)

# %%
mse_forest = np.mean((y_test - y_pred_forest)**2)

# %%
pd.DataFrame({"y_test":y_test , "y_pred_forest":y_pred_forest})
# Out:
#            y_test  y_pred_forest
# 17076   37609.304    42077.00321
# 14390   31224.186    33844.81419
# 19821   62247.997    62754.86666
# 21177   43183.565    41279.83526
# 11865     359.114      401.97376
# 14394    3485.623     3342.50237
# 17075   94791.671    92880.45593
# 21172   34778.046    33651.98822
# 13093   25745.719    26717.79184
# 17080    4405.011     3805.84778
# 23865     562.270      517.83854
# 15705    3380.168     3662.54873
# 19822   32563.617    31102.33140
# 23870  130710.818   126867.87899
# 13095   80612.706    83450.92355
# 11869   25745.189    25915.24372
# 14386     391.823      422.66496
# 15698   35255.237    40078.25494

# %%
mse_forest
# Out:
# 4738234.64133375

# %%
rmse = np.sqrt(mse_forest)

# %%
rmse
# Out:
# 2176.7486399062595

# %%
data_ind.shape
# Out:
# (90, 4)

# %%
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(4 , input_dim = 3 , activation = "relu"))
model.add(Dense(8 , activation = "relu"))
model.add(Dense(2 , activation = "relu"))
model.add(Dense(1 , activation = "linear"))

# %%
model.compile(loss = 'mse' , optimizer = "adam" )

# %%
model = model.fit(x_train , y_train , batch_size = 5 , validation_split = 0.20 , epochs = 100)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 13ms/step - loss: 3354903552.0000 - val_loss: 2355619584.0000
# Epoch 2/100
# 12/12 [==============================] - 0s 4ms/step - loss: 3354891776.0000 - val_loss: 2355611136.0000
# Epoch 3/100
# 12/12 [==============================] - 0s 5ms/step - loss: 3354878720.0000 - val_loss: 2355602432.0000
# Epoch 4/100
# 12/12 [==============================] - 0s 5ms/step - loss: 3354864896.0000 - val_loss: 2355592704.0000
# Epoch 5/100
# 12/12 [==============================] - 0s 6ms/step - loss: 3354849024.0000 - val_loss: 2355581440.0000
# Epoch 6/100
# 12/12 [==============================] - 0s 5ms/step - loss: 3354833152.0000 - val_loss: 2355569408.0000
# Epoch 7/100
# 12/12 [==============================] - 0s 5ms/step - loss: 3354814464.0000 - val_loss: 2355557376.0000
# Epoch 8/100
# 12/12 [==============================] - 0s 4ms/step - loss: 3354796800.0000 - val_loss: 2355543040.0000
# Epoch 9/100
# ...
